# %% [markdown]
# # SCIDS API
#
# __author__: Yongchan Kwon
#
# __email__: yk3012@columbia.edu
#
#
# Application Programmable Interface (API) is **a way for two or more computer programs to communicate with each other**. For data analysts, API is very useful when you want to retrieve the data from some websites. Although many websites allow you to download data with a single click on a browser, the ability to automatically query data without a single click requires some special skills.
#
# We revisit the COVID-19 dataset from CDC (https://data.cdc.gov/Case-Surveillance/COVID-19-Case-Surveillance-Public-Use-Data-with-Ge/n8mc-b4w4). Before, we used a retrieved dataset, now we are going to query from the CDC webstie.

# %%
import requests # to download data
import pandas as pd

URL = "https://data.cdc.gov/resource/n8mc-b4w4.json" 
response = requests.get(url=URL)
response # <Response [200]> means "OK!"
# Out:
# <Response [200]>

# %% [markdown]
# - Your status code should be `200` if you provided the correct credentials and everything. There are many different types of statuses that can sometimes help you debug your request.
#
# References
# - https://dev.socrata.com/docs/response-codes.html
# - https://httpstatusdogs.com/

# %%
wrong_URL = "https://data.cdc.gov/resource/wrong-url.json"
response = requests.get(url=wrong_URL)
response # <Response [404]> means "Not found :("
# Out:
# <Response [404]>

# %%
response = requests.get(url=URL)
print('Response code: ', response.status_code) # status_code returns the response. 
print('URL: ', response.url)
# Out:
# Response code:  200
# URL:  https://data.cdc.gov/resource/n8mc-b4w4.json

# %% [markdown]
# - The retrieved data are stored in `.text`.

# %%
response.text # raw data queried by requests.get() # hard to interpret......
# Out:
# '[{"case_month":"2020-12","res_state":"SC","state_fips_code":"45","res_county":"GREENVILLE","county_fips_code":"45045","age_group":"65+ years","sex":"Female","race":"White","ethnicity":"Non-Hispanic/Latino","process":"Missing","exposure_yn":"Missing","current_status":"Laboratory-confirmed case","symptom_status":"Missing","hosp_yn":"Missing","icu_yn":"Missing","death_yn":"Missing"}\n,{"case_month":"2021-06","res_state":"UT","state_fips_code":"49","res_county":"CACHE","county_fips_code":"49005","age_group":"18 to 49 years","sex":"Male","race":"White","ethnicity":"Non-Hispanic/Latino","case_positive_specimen":"0","process":"Missing","exposure_yn":"Missing","current_status":"Laboratory-confirmed case","symptom_status":"Missing","hosp_yn":"No","icu_yn":"Missing","death_yn":"Unknown"}\n,{"case_month":"2021-01","res_state":"OH","state_fips_code":"39","res_county":"CLERMONT","county_fips_code":"39025","age_group":"18 to 49 years","sex":"NA","race":"NA","ethnicity":"NA","process":"Missing","exposure_yn":"Missing","current_status":"Laboratory-confirmed case","symptom_status":"Missing","hosp_yn":"Missing","icu_yn":"Missing","death_yn":"NA"}\n,{"case_month":"2021-08","res_state":"CO","state_fips_code":"08","res_county":"ADAMS","county_fips_code":"08001","age_group":"18 to 49 years","sex":"Female","race":"Missing","ethnicity":"Unknown","process":"Missing","exposure_yn":"Missing","current_status":"Laboratory-confirmed case","symptom_status":"Missing","hosp_yn":"Missing","icu_yn":"Missing","death_yn":"Missing"}\n,{"case_month":"2021-10","res_state":"FL","state_fips_code":"12","res_county":"ORANGE","county_fips_code":"12095","age_group":"18 to 49 years","sex":"Male","race":"NA","ethnicity":"NA","process":"Missing","exposure_yn":"Missing","current_status":"Laboratory-confirmed case","symptom_status":"Missing","hosp_yn":"Missing","icu_yn":"Missing","death_yn":"Missing"}\n,{"case_month":"2022-08","res_state":"CA","state_fips_code":"06","res_county":"SANTA CRUZ","county_fips_code":"06087","age_group":"50 to 64 years","sex":"Male","race":"NA","ethnicity":"NA","process":"Missing","exposure_yn":"Missing","current_status":"Laboratory-confirmed case","symptom_status":"Asymptomatic","hosp_yn":"Missing","icu_yn":"Missing","death_yn":"Missing"}\n,{"case_month":"2021-12","res_state":"VA","state_fips_code":"51","res_county":"CHESTERFIELD","county_fips_code":"51041","age_group":"50 to 64 years","sex":"Male","race":"White","ethnicity":"Unknown","process":"Missing","exposure_yn":"Missing","current_status":"Laboratory-confirmed case","symptom_status":"Missing","hosp_yn":"Missing","icu_yn":"Missing","death_yn":"Missing"}\n,{"case_month":"2022-07","res_state":"NY","state_fips_code":"36","res_county":"QUEENS","county_fips_code":"36081","age_group":"18 to 49 years","sex":"Female","race":"Unknown","ethnicity":"Non-Hispanic/Latino","case_positive_specimen":"0","process":"Missing","exposure_yn":"Missing","current_status":"Laboratory-confirmed case","symptom_status":"Unknown","hosp_yn":"Missing","icu_yn":"Missing","death_yn":"Missing"}\n,{"case_month":"2020-12","res_state":"CA","state_fips_code":"06","res_county":"SAN BERNARDINO","county_fips_code":"06071","age_group":"50 to 64 years","sex":"Female","race":"White","ethnicity":"Non-Hispanic/Latino","case_onset_interval":"0","process":"Missing","exposure_yn":"Missing","current_status":"Laboratory-confirmed case","symptom_status":"Symptomatic","hosp_yn":"No","icu_yn":"Missing","death_yn":"Missing"}\n,{"case_month":"2022-05","res_state":"FL","state_fips_code":"12","res_county":"SARASOTA","county_fips_code":"12115","age_group":"65+ years","sex":"Female","race":"White","ethnicity":"Non-Hispanic/Latino","case_positive_specimen":"0","process":"Missing","exposure_yn":"Missing","current_status":"Laboratory-confirmed case","symptom_status":"Missing","hosp_yn":"Missing","icu_yn":"Missing","death_yn":"Missing"}\n,{"case_month":"2022-02","res_state":"SD","state_fips_code":"46","res_county":"PENNINGTON","county_fips_code":"46103","a ...

# %%
data=response.json() # Note that our data is stored in json
type(data), len(data)
# Out:
# (list, 1000)

# %%
data[0] # dictionary type
# Out:
# {'case_month': '2020-12',
#  'res_state': 'SC',
#  'state_fips_code': '45',
#  'res_county': 'GREENVILLE',
#  'county_fips_code': '45045',
#  'age_group': '65+ years',
#  'sex': 'Female',
#  'race': 'White',
#  'ethnicity': 'Non-Hispanic/Latino',
#  'process': 'Missing',
#  'exposure_yn': 'Missing',
#  'current_status': 'Laboratory-confirmed case',
#  'symptom_status': 'Missing',
#  'hosp_yn': 'Missing',
#  'icu_yn': 'Missing',
#  'death_yn': 'Missing'}

# %%
pd.DataFrame(data)
# Out:
#     case_month res_state state_fips_code  res_county county_fips_code  \
# 0      2020-12        SC              45  GREENVILLE            45045
# 1      2021-06        UT              49       CACHE            49005
# 2      2021-01        OH              39    CLERMONT            39025
# 3      2021-08        CO              08       ADAMS            08001
# 4      2021-10        FL              12      ORANGE            12095
# ..         ...       ...             ...         ...              ...
# 995    2022-01        TX              48   GALVESTON            48167
# 996    2022-01        OH              39   FAIRFIELD            39045
# 997    2021-09        NC              37    CABARRUS            37025
# 998    2021-09        IN              18      PORTER            18127
# 999    2021-04        OH              39        WOOD            39173
#
#           age_group     sex     race            ethnicity  \
# 0         65+ years  Female    White  Non-Hispanic/Latino
# 1    18 to 49 years    Male    White  Non-Hispanic/Latino
# 2    18 to 49 years      NA       NA                   NA
# 3    18 to 49 years  Female  Missing              Unknown
# 4    18 to 49 years    Male       NA                   NA
# ..              ...     ...      ...                  ...
# 995       65+ years  Female    Black      Hispanic/Latino
# 996  50 to 64 years  Female  Unknown  Non-Hispanic/Latino
# 997    0 - 17 years  Female    White  Non-Hispanic/Latino
# 998    0 - 17 years  Female    White  Non-Hispanic/Latino
# 999  18 to 49 years  Female    White  Non-Hispanic/Latino
#
#                  process exposure_yn             current_status  \
# 0                Missing     Missing  Laboratory-confirmed case
# 1                Missing     Missing  Laboratory-confirmed case
# 2                Missing     Missing  Laboratory-confirmed case
# 3                Missing     Missing  Laboratory-confirmed case
# 4                Missing     Missing  Laboratory-confirmed case
# ..                   ...         ...                        ...
# 995              Missing     Missing  Laboratory-confirmed case
# 996  Clinical evaluation     Unknown  Laboratory-confirmed case
# 997              Missing     Missing  Laboratory-confirmed case
# 998              Missing     Missing  Laboratory-confirmed case
# 999  Clinical evaluation         Yes  Laboratory-confirmed case
#
#     symptom_status  hosp_yn   icu_yn death_yn case_positive_specimen  \
# 0          Missing  Missing  Missing  Missing                    NaN
# 1          Missing       No  Missing  Unknown                      0
# 2          Missing  Missing  Missing       NA                    NaN
# 3          Missing  Missing  Missing  Missing                    NaN
# 4          Missing  Missing  Missing  Missing                    NaN
# ..             ...      ...      ...      ...                    ...
# 995        Missing  Missing  Missing  Missing                    NaN
# 996    Symptomatic       No  Missing       No                      1
# 997        Unknown  Unknown  Unknown       No                      0
# 998        Missing       No  Missing       No                      0
# 999    Symptomatic       No       No       No                      0
#
#     case_onset_interval underlying_conditions_yn
# 0                   NaN                      NaN
# 1                   NaN                      NaN
# 2                   NaN                      NaN
# 3                   NaN                      NaN
# 4                   NaN                      NaN
# ..                  ...                      ...
# 995                 NaN                      NaN
# 996                   0                      NaN
# 997                 NaN                      NaN
# 998                 NaN                      NaN
# 999                   0                      NaN
#
# [1000 rows x 19 columns]

# %% [markdown]
# ### Useful parameters for calling API
#
# Note that the `dataframe` we downloaded has only 1000 rows, but the original dataset has more than 87 million records. With the argument `params`, one of the core arguments in `requests.get()`, we can selectively retrieve data.
#
# Reference
#  - https://dev.socrata.com/docs/queries/

# %% [markdown]
# - `$offset`: The index of the result array where to start the returned list of results (default: 0).
# - `$limit`: The number of results to return (default: 1000).

# %%
params={'$offset': 0, 
        '$limit': 10} # define it as a Python dictionary
response = requests.get(url=URL, params=params)
pd.DataFrame(response.json())
# Out:
#   case_month res_state state_fips_code       res_county county_fips_code  \
# 0    2021-11        MI              26          OAKLAND            26125
# 1    2021-08        AZ              04         MARICOPA            04013
# 2    2021-12        IL              17             COOK            17031
# 3    2021-04        CO              08           DENVER            08031
# 4    2020-09        NV              32            CLARK            32003
# 5    2021-12        NC              37         GUILFORD            37081
# 6    2020-11        FL              12              LEE            12071
# 7    2021-09        UT              49             UTAH            49049
# 8    2022-05        MD              24  PRINCE GEORGE'S            24033
# 9    2022-04        TX              48        FORT BEND            48157
#
#         age_group     sex     race            ethnicity               process  \
# 0  50 to 64 years  Female  Unknown              Unknown               Missing
# 1  18 to 49 years    Male  Missing      Hispanic/Latino               Missing
# 2  18 to 49 years  Female       NA                   NA               Missing
# 3    0 - 17 years  Female    White      Hispanic/Latino               Missing
# 4  18 to 49 years  Female    Black  Non-Hispanic/Latino  Routine surveillance
# 5  50 to 64 years    Male    Black  Non-Hispanic/Latino               Missing
# 6  50 to 64 years  Female    White  Non-Hispanic/Latino               Missing
# 7  50 to 64 years  Female    White  Non-Hispanic/Latino               Missing
# 8  18 to 49 years    Male    Black              Missing               Missing
# 9  18 to 49 years  Female    Asian  Non-Hispanic/Latino               Missing
#
#   exposure_yn             current_status symptom_status  hosp_yn   icu_yn  \
# 0     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 1     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 2     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 3     Missing  Laboratory-confirmed case    Symptomatic       No  Missing
# 4     Missing  Laboratory-confirmed case    Symptomatic       No       No
# 5     Missing  Laboratory-confirmed case        Unknown  Unknown  Unknown
# 6     Missing  Laboratory-confirmed case    Symptomatic       No  Missing
# 7         Yes  Laboratory-confirmed case    Symptomatic       No       No
# 8     Missing              Probable Case    Symptomatic  Missing  Missing
# 9     Missing  Laboratory-confirmed case    Symptomatic       No  Missing
#
#   death_yn case_positive_specimen case_onset_interval underlying_conditions_yn
# 0  Unknown                    NaN                 NaN                      NaN
# 1  Missing                    NaN                 NaN                      NaN
# 2  Missing                      1                   0                      NaN
# 3       NA                    NaN                   0                      NaN
# 4       No                      0                   0                      Yes
# 5       No                      0                 NaN                      NaN
# 6       No                    NaN                   0                      NaN
# 7  Unknown                      0                   0                      Yes
# 8       No                    NaN                   0                      NaN
# 9       No                    NaN                   0                      NaN

# %%
params={'$offset': 5, 
        '$limit': 10} # starts from the index 5 and retrieves 10 records
response = requests.get(url=URL, params=params)
pd.DataFrame(response.json())
# Out:
#   case_month res_state state_fips_code       res_county county_fips_code  \
# 0    2021-12        NC              37         GUILFORD            37081
# 1    2020-11        FL              12              LEE            12071
# 2    2021-09        UT              49             UTAH            49049
# 3    2022-05        MD              24  PRINCE GEORGE'S            24033
# 4    2022-04        TX              48        FORT BEND            48157
# 5    2020-11        PA              42        LANCASTER            42071
# 6    2020-11        WI              55        MILWAUKEE            55079
# 7    2022-01        PA              42       MONTGOMERY            42091
# 8    2022-09        CA              06           ORANGE            06059
# 9    2022-02        CT              09        NEW HAVEN            09009
#
#         age_group      sex     race            ethnicity  \
# 0  50 to 64 years     Male    Black  Non-Hispanic/Latino
# 1  50 to 64 years   Female    White  Non-Hispanic/Latino
# 2  50 to 64 years   Female    White  Non-Hispanic/Latino
# 3  18 to 49 years     Male    Black              Missing
# 4  18 to 49 years   Female    Asian  Non-Hispanic/Latino
# 5       65+ years     Male    White  Non-Hispanic/Latino
# 6  18 to 49 years   Female    White  Non-Hispanic/Latino
# 7       65+ years   Female    White  Non-Hispanic/Latino
# 8    0 - 17 years     Male  Unknown  Non-Hispanic/Latino
# 9  18 to 49 years  Missing  Missing                   NA
#
#   case_positive_specimen  process exposure_yn             current_status  \
# 0                      0  Missing     Missing  Laboratory-confirmed case
# 1                    NaN  Missing     Missing  Laboratory-confirmed case
# 2                      0  Missing         Yes  Laboratory-confirmed case
# 3                    NaN  Missing     Missing              Probable Case
# 4                    NaN  Missing     Missing  Laboratory-confirmed case
# 5                      0  Missing     Missing  Laboratory-confirmed case
# 6                    NaN  Missing     Missing  Laboratory-confirmed case
# 7                      0  Missing     Missing  Laboratory-confirmed case
# 8                    NaN  Missing     Missing  Laboratory-confirmed case
# 9                    NaN  Missing     Missing  Laboratory-confirmed case
#
#   symptom_status  hosp_yn   icu_yn death_yn case_onset_interval  \
# 0        Unknown  Unknown  Unknown       No                 NaN
# 1    Symptomatic       No  Missing       No                   0
# 2    Symptomatic       No       No  Unknown                   0
# 3    Symptomatic  Missing  Missing       No                   0
# 4    Symptomatic       No  Missing       No                   0
# 5    Symptomatic  Unknown  Unknown  Unknown                   0
# 6        Missing  Unknown  Missing  Unknown                 NaN
# 7    Symptomatic  Unknown  Unknown  Unknown                   0
# 8        Unknown  Missing  Missing  Missing                 NaN
# 9        Missing  Missing  Missing  Missing                 NaN
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN
# 2                      Yes
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN

# %% [markdown]
# - Outputs from `requests.get()` are not same for some reasons. To avoid retrieving the same data twice, you may want to use `$order`.
#
# Reference: https://dev.socrata.com/docs/paging.html

# %%
params={'$offset': 5, 
        '$limit': 10,
        '$order': 'case_month'}
response = requests.get(url=URL, params=params)
pd.DataFrame(response.json())
# Out:
#   case_month res_state state_fips_code  res_county county_fips_code  \
# 0    2020-01        GA              13      COFFEE            13069
# 1    2020-01        GA              13      COFFEE            13069
# 2    2020-01        GA              13      COFFEE            13069
# 3    2020-01        GA              13      COFFEE            13069
# 4    2020-01        GA              13      COFFEE            13069
# 5    2020-01        GA              13      COFFEE            13069
# 6    2020-01        GA              13      COFFEE            13069
# 7    2020-01        GA              13      COFFEE            13069
# 8    2020-01        CA              06  STANISLAUS            06099
# 9    2020-01        CA              06  STANISLAUS            06099
#
#         age_group     sex race ethnicity  process exposure_yn  \
# 0              NA      NA   NA        NA  Missing     Missing
# 1              NA      NA   NA        NA  Missing     Missing
# 2              NA      NA   NA        NA  Missing     Missing
# 3              NA      NA   NA        NA  Missing     Missing
# 4              NA      NA   NA        NA  Missing     Missing
# 5              NA      NA   NA        NA  Missing     Missing
# 6              NA      NA   NA        NA  Missing     Missing
# 7              NA      NA   NA        NA  Missing     Missing
# 8  18 to 49 years  Female   NA        NA  Missing     Missing
# 9  18 to 49 years  Female   NA        NA  Missing     Missing
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn
# 0  Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 1  Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 2  Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 3  Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 4  Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 5  Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 6  Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 7  Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 8  Laboratory-confirmed case        Unknown  Missing  Missing  Missing
# 9  Laboratory-confirmed case        Unknown  Missing  Missing  Missing

# %% [markdown]
# - Combining all, we can collect the entire data from the website using `for` loop.

# %%
rows=[]
n_query_per_iter=1000
for i in range(5):
  print(f'Query data from {i*n_query_per_iter} to {(i+1)*n_query_per_iter}')
  params={'$offset': i*n_query_per_iter, 
          '$limit': n_query_per_iter,
          '$order':'case_month'}
  response = requests.get(url=URL, params=params)
  if response.status_code == 200:
    rows.extend(response.json()) # note that the output of .json() is list
  else:
    raise f'Check status_code: {response.status_code}!!'

df_paged=pd.DataFrame(rows) # covert list to pandas.DataFrame
# Out:
# Query data from 0 to 1000
# Query data from 1000 to 2000
# Query data from 2000 to 3000
# Query data from 3000 to 4000
# Query data from 4000 to 5000

# %%
df_paged
# Out:
#      case_month res_state state_fips_code res_county county_fips_code  \
# 0       2020-01        GA              13     COFFEE            13069
# 1       2020-01        GA              13     COFFEE            13069
# 2       2020-01        GA              13     COFFEE            13069
# 3       2020-01        GA              13     COFFEE            13069
# 4       2020-01        GA              13     COFFEE            13069
# ...         ...       ...             ...        ...              ...
# 4995    2020-01        GA              13         NA               NA
# 4996    2020-01        GA              13         NA               NA
# 4997    2020-01        GA              13         NA               NA
# 4998    2020-01        GA              13         NA               NA
# 4999    2020-01        GA              13         NA               NA
#
#      age_group sex race ethnicity  process exposure_yn  \
# 0           NA  NA   NA        NA  Missing     Missing
# 1           NA  NA   NA        NA  Missing     Missing
# 2           NA  NA   NA        NA  Missing     Missing
# 3           NA  NA   NA        NA  Missing     Missing
# 4           NA  NA   NA        NA  Missing     Missing
# ...        ...  ..  ...       ...      ...         ...
# 4995        NA  NA   NA        NA  Missing     Missing
# 4996        NA  NA   NA        NA  Missing     Missing
# 4997        NA  NA   NA        NA  Missing     Missing
# 4998        NA  NA   NA        NA  Missing     Missing
# 4999        NA  NA   NA        NA  Missing     Missing
#
#                  current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0     Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 1     Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 2     Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 3     Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 4     Laboratory-confirmed case        Missing  Missing  Missing      Yes
# ...                         ...            ...      ...      ...      ...
# 4995  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4996  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4997  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4998  Laboratory-confirmed case        Missing  Missing  Missing      Yes
# 4999  Laboratory-confirmed case        Missing  Missing  Missing      Yes
#
#      case_onset_interval underlying_conditions_yn case_positive_specimen
# 0                    NaN                      NaN                    NaN
# 1                    NaN                      NaN                    NaN
# 2                    NaN                      NaN                    NaN
# 3                    NaN                      NaN                    NaN
# 4                    NaN                      NaN                    NaN
# ...                  ...                      ...                    ...
# 4995                   0                      NaN                    NaN
# 4996                   0                      NaN                    NaN
# 4997                   0                      NaN                    NaN
# 4998                 NaN                      NaN                    NaN
# 4999                 NaN                      NaN                    NaN
#
# [5000 rows x 19 columns]

# %% [markdown]
# - `$select`: The set of columns to be returned (default all columns).

# %%
params={'$offset': 5, 
        '$limit': 10,
        '$select': "case_month, res_state, res_county, age_group,	sex, race"} 
response = requests.get(url=URL, params=params)
pd.DataFrame(response.json())
# Out:
#   case_month res_state       res_county       age_group     sex     race
# 0    2022-01        IL             COOK       65+ years  Female    Black
# 1    2022-02        FL        ST. JOHNS  18 to 49 years  Female    White
# 2    2021-07        MN         HENNEPIN  50 to 64 years  Female    White
# 3    2021-11        MO           JASPER       65+ years  Female    White
# 4    2020-11        VA  ALEXANDRIA CITY  18 to 49 years  Female       NA
# 5    2022-01        CO             WELD    0 - 17 years  Female  Missing
# 6    2021-05        MA            ESSEX    0 - 17 years    Male    White
# 7    2020-12        CO               NA    0 - 17 years    Male       NA
# 8    2022-01        AZ         MARICOPA  50 to 64 years    Male    White
# 9    2022-01        NJ        MIDDLESEX  18 to 49 years  Female    Black

# %% [markdown]
# - `variable_name` : retrieve data satisfying conditions (Note that no `$` character here).

# %%
params={'$offset': 5, 
        '$limit': 10,
        '$select': "case_month, res_state, res_county, age_group,	sex,	race",
        'res_state':'NY',
        'sex': 'Female'
        }
response = requests.get(url=URL, params=params)
pd.DataFrame(response.json())
# Out:
#   case_month res_state   res_county       age_group     sex  \
# 0    2021-02        NY  WESTCHESTER  18 to 49 years  Female
# 1    2020-09        NY   CHAUTAUQUA  18 to 49 years  Female
# 2    2020-05        NY     TOMPKINS  18 to 49 years  Female
# 3    2020-10        NY     ALLEGANY       65+ years  Female
# 4    2021-11        NY      CLINTON       65+ years  Female
# 5    2020-04        NY     ROCKLAND    0 - 17 years  Female
# 6    2021-10        NY     SULLIVAN  50 to 64 years  Female
# 7    2022-06        NY     DUTCHESS    0 - 17 years  Female
# 8    2020-07        NY       ONEIDA  18 to 49 years  Female
# 9    2020-12        NY        BRONX    0 - 17 years  Female
#
#                             race
# 0                          Black
# 1                        Unknown
# 2                        Unknown
# 3                        Unknown
# 4                        Missing
# 5                        Unknown
# 6                        Unknown
# 7                        Unknown
# 8                        Unknown
# 9  American Indian/Alaska Native

# %%
params={'$offset': 5, 
        '$limit': 10,
        '$select': "case_month, res_state, res_county, age_group,	sex,	race",
        '$where':"res_state='NY' AND sex='Female'", # equivalent but more sql style
        }
response = requests.get(url=URL, params=params)
pd.DataFrame(response.json())
# Out:
#   case_month res_state   res_county       age_group     sex  \
# 0    2021-02        NY  WESTCHESTER  18 to 49 years  Female
# 1    2020-09        NY   CHAUTAUQUA  18 to 49 years  Female
# 2    2020-05        NY     TOMPKINS  18 to 49 years  Female
# 3    2020-10        NY     ALLEGANY       65+ years  Female
# 4    2021-11        NY      CLINTON       65+ years  Female
# 5    2020-04        NY     ROCKLAND    0 - 17 years  Female
# 6    2021-10        NY     SULLIVAN  50 to 64 years  Female
# 7    2022-06        NY     DUTCHESS    0 - 17 years  Female
# 8    2020-07        NY       ONEIDA  18 to 49 years  Female
# 9    2020-12        NY        BRONX    0 - 17 years  Female
#
#                             race
# 0                          Black
# 1                        Unknown
# 2                        Unknown
# 3                        Unknown
# 4                        Missing
# 5                        Unknown
# 6                        Unknown
# 7                        Unknown
# 8                        Unknown
# 9  American Indian/Alaska Native

# %%
params={'$offset': 5, 
        '$limit': 10,
        '$select': "case_month, res_state, res_county, age_group,	sex,	race",
        '$where':"res_state='NY' AND (sex='Female' OR sex='Male')", # $where offers more versatile functions.
        }
response = requests.get(url=URL, params=params)
pd.DataFrame(response.json())
# Out:
#   case_month res_state   res_county       age_group     sex     race
# 0    2021-04        NY      ONTARIO  18 to 49 years  Female  Unknown
# 1    2021-10        NY   LIVINGSTON  18 to 49 years  Female  Unknown
# 2    2021-02        NY  WESTCHESTER  18 to 49 years  Female    Black
# 3    2020-09        NY   CHAUTAUQUA  18 to 49 years  Female  Unknown
# 4    2020-05        NY     TOMPKINS  18 to 49 years  Female  Unknown
# 5    2022-01        NY       SENECA  18 to 49 years    Male       NA
# 6    2020-10        NY     ALLEGANY       65+ years  Female  Unknown
# 7    2021-12        NY       WARREN  50 to 64 years    Male  Missing
# 8    2021-11        NY      CLINTON       65+ years  Female  Missing
# 9    2020-04        NY     ROCKLAND    0 - 17 years  Female  Unknown

# %%
params={'$offset': 5, 
        '$limit': 10,
        '$select': "case_month, res_state, res_county, age_group,	sex,	race",
        '$where':"res_state='NY' AND (sex IN ('Female','Male'))", # $where offers more versatile functions.
        }
response = requests.get(url=URL, params=params)
pd.DataFrame(response.json())
# Out:
#   case_month res_state   res_county       age_group     sex     race
# 0    2021-04        NY      ONTARIO  18 to 49 years  Female  Unknown
# 1    2021-10        NY   LIVINGSTON  18 to 49 years  Female  Unknown
# 2    2021-02        NY  WESTCHESTER  18 to 49 years  Female    Black
# 3    2020-09        NY   CHAUTAUQUA  18 to 49 years  Female  Unknown
# 4    2020-05        NY     TOMPKINS  18 to 49 years  Female  Unknown
# 5    2022-01        NY       SENECA  18 to 49 years    Male       NA
# 6    2020-10        NY     ALLEGANY       65+ years  Female  Unknown
# 7    2021-12        NY       WARREN  50 to 64 years    Male  Missing
# 8    2021-11        NY      CLINTON       65+ years  Female  Missing
# 9    2020-04        NY     ROCKLAND    0 - 17 years  Female  Unknown

# %%
params={'$offset': 5, 
        '$limit': 10,
        '$select': "case_month, res_state, res_county, age_group,	sex,	race",
        '$where': "res_state='NY' AND (sex IN ('Female','Male')) AND (case_month between '2019-05' and '2020-06')", # $where offers more versatile functions.
        }
response = requests.get(url=URL, params=params)
pd.DataFrame(response.json())
# Out:
#   case_month res_state res_county       age_group     sex   race
# 0    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 1    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 2    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 3    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 4    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 5    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 6    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 7    2020-01        NY     ONEIDA  18 to 49 years  Female  White
# 8    2020-01        NY     ONEIDA  18 to 49 years  Female  White
# 9    2020-01        NY     ONEIDA  18 to 49 years  Female  White

# %%
params={'$offset': 5, 
        '$limit': 10,
        '$select': "case_month, res_state, res_county, age_group,	sex,	race",
        '$where': ("(res_state='NY') AND"
                   "(sex IN ('Female','Male')) AND"
                   "(case_month between '2019-05' and '2020-02')"), # Line breaking
        }
response = requests.get(url=URL, params=params)
pd.DataFrame(response.json())
# Out:
#   case_month res_state res_county       age_group     sex   race
# 0    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 1    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 2    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 3    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 4    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 5    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 6    2020-01        NY   HERKIMER  18 to 49 years  Female     NA
# 7    2020-01        NY     ONEIDA  18 to 49 years  Female  White
# 8    2020-01        NY     ONEIDA  18 to 49 years  Female  White
# 9    2020-01        NY     ONEIDA  18 to 49 years  Female  White

# %% [markdown]
# ## **Remarks**
# - Different websites may use different protocols. Always double check the data provider's manual.
#  - CDC uses `$select`, but the example below uses `get`
# - Related to this, you may want to use the provider's official API, not `requests`. (Throughout this course, you can safely assume that everything can be done with `requests`)

# %% [markdown]
# ### [Example] Dependence on Russian and Ukrainian Imports
#
# As the world is changing this week, we can try to understand how important Russian and Ukrainian imports are to the US. [Census.Gov](https://www.census.gov/data/developers/data-sets/international-trade.html) has international trade data exposed for us to download.
#
# Please pay particular attention to the example calls under **Monthly International Trade Time Series - Imports**.

# %%
base_url="http://api.census.gov/data/timeseries/intltrade/imports/enduse?"
params = {"get": "CTY_CODE,CTY_NAME,I_ENDUSE,I_ENDUSE_LDESC,GEN_VAL_MO,CON_VAL_MO",
          "time": "2013-01"}
resp=requests.get(base_url, params=params)

# %%
df=pd.DataFrame(resp.json())
df
# Out:
#               0           1         2  \
# 0      CTY_CODE    CTY_NAME  I_ENDUSE
# 1          4050     FINLAND         -
# 2          4635  KYRGYZSTAN         -
# 3          4641     MOLDOVA         -
# 4          4642  TAJIKISTAN         -
# ...         ...         ...       ...
# 13039      4550      POLAND     50040
# 13040      4621      RUSSIA     50040
# 13041      4623     UKRAINE     50040
# 13042      4633     GEORGIA     50040
# 13043      4700       SPAIN     50040
#
#                                                        3           4  \
# 0                                         I_ENDUSE_LDESC  GEN_VAL_MO
# 1                    TOTAL IMPORTS FOR ALL END-USE CODES   319554327
# 2                    TOTAL IMPORTS FOR ALL END-USE CODES       17592
# 3                    TOTAL IMPORTS FOR ALL END-USE CODES     3766608
# 4                    TOTAL IMPORTS FOR ALL END-USE CODES       10311
# ...                                                  ...         ...
# 13039  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...      113231
# 13040  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...       20620
# 13041  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...        5205
# 13042  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...       83464
# 13043  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...    19435961
#
#                 5        6
# 0      CON_VAL_MO     time
# 1       335786013  2013-01
# 2           17592  2013-01
# 3         3640049  2013-01
# 4           10311  2013-01
# ...           ...      ...
# 13039      113231  2013-01
# 13040       20620  2013-01
# 13041        5205  2013-01
# 13042       83464  2013-01
# 13043    19435961  2013-01
#
# [13044 rows x 7 columns]

# %%
df.rename(columns=df.iloc[0]).drop(df.index[0])
# Out:
#       CTY_CODE      CTY_NAME I_ENDUSE  \
# 1         4050       FINLAND        -
# 2         4635    KYRGYZSTAN        -
# 3         4641       MOLDOVA        -
# 4         4642    TAJIKISTAN        -
# 5         4643  TURKMENISTAN        -
# ...        ...           ...      ...
# 13039     4550        POLAND    50040
# 13040     4621        RUSSIA    50040
# 13041     4623       UKRAINE    50040
# 13042     4633       GEORGIA    50040
# 13043     4700         SPAIN    50040
#
#                                           I_ENDUSE_LDESC GEN_VAL_MO  \
# 1                    TOTAL IMPORTS FOR ALL END-USE CODES  319554327
# 2                    TOTAL IMPORTS FOR ALL END-USE CODES      17592
# 3                    TOTAL IMPORTS FOR ALL END-USE CODES    3766608
# 4                    TOTAL IMPORTS FOR ALL END-USE CODES      10311
# 5                    TOTAL IMPORTS FOR ALL END-USE CODES     710820
# ...                                                  ...        ...
# 13039  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...     113231
# 13040  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...      20620
# 13041  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...       5205
# 13042  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...      83464
# 13043  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...   19435961
#
#       CON_VAL_MO     time
# 1      335786013  2013-01
# 2          17592  2013-01
# 3        3640049  2013-01
# 4          10311  2013-01
# 5         710820  2013-01
# ...          ...      ...
# 13039     113231  2013-01
# 13040      20620  2013-01
# 13041       5205  2013-01
# 13042      83464  2013-01
# 13043   19435961  2013-01
#
# [13043 rows x 7 columns]

# %%
# Paging: retrieve a subset - or a page - at a time
years = list(range(2019, 2021))
months = range(1, 13)

dfs = []
for year in years:
    print(year)
    for month in months:
        month = month if month >= 10 else "0" + str(month)
        base_url = "http://api.census.gov/data/timeseries/intltrade/imports/enduse"
        params = {"get": "CTY_CODE,CTY_NAME,I_ENDUSE,I_ENDUSE_LDESC,GEN_VAL_MO,CON_VAL_MO",
                  "time": "{YEAR}-{MONTH}".format(YEAR=year, MONTH=month)}
        resp = requests.get(base_url, params=params)
        dat = resp.json()
        df = pd.DataFrame(dat[1:], columns=dat[0])
        dfs.append(df)
# Out:
# 2019
# 2020

# %%
bdf = pd.concat(dfs)
bdf
# Out:
#       CTY_CODE                 CTY_NAME I_ENDUSE  \
# 0            -  TOTAL FOR ALL COUNTRIES        -
# 1         0003           EUROPEAN UNION        -
# 2         0014    PACIFIC RIM COUNTRIES        -
# 3         0017                 CAFTA-DR        -
# 4         0020                    NAFTA        -
# ...        ...                      ...      ...
# 13624     7790                    KENYA    50040
# 13625     7850                MAURITIUS    50040
# 13626     7880               MADAGASCAR    50040
# 13627     7910             SOUTH AFRICA    50040
# 13628     7XXX                   AFRICA    50040
#
#                                           I_ENDUSE_LDESC    GEN_VAL_MO  \
# 0                    TOTAL IMPORTS FOR ALL END-USE CODES  203980735535
# 1                    TOTAL IMPORTS FOR ALL END-USE CODES   35062078374
# 2                    TOTAL IMPORTS FOR ALL END-USE CODES   73806622920
# 3                    TOTAL IMPORTS FOR ALL END-USE CODES    1777592697
# 4                    TOTAL IMPORTS FOR ALL END-USE CODES   50906264625
# ...                                                  ...           ...
# 13624  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...         69827
# 13625  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...        560729
# 13626  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...         42491
# 13627  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...        216754
# 13628  OTHER (MOVIES, MISCELLANEOUS IMPORTS, AND SPEC...       1459472
#
#          CON_VAL_MO     time
# 0      206290514519  2019-01
# 1       35649021589  2019-01
# 2       74756324892  2019-01
# 3        1778013540  2019-01
# 4       50832244194  2019-01
# ...             ...      ...
# 13624         69827  2020-01
# 13625        560729  2020-01
# 13626         42491  2020-01
# 13627        216754  2020-01
# 13628       1459472  2020-01
#
# [27385 rows x 7 columns]
